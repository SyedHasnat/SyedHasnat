# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedHasnat/SyedHasnat/blob/main/Chapter_3(Conditional_execution).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Conditional Execution** (Reference: Python For Everbody)
#
# *   Boolean expressions
# *   Logical operators
# *   Conditional execution
# *   Alternative execution
# *   Chained conditionals
# *   Nested conditionals

# %% [markdown]
# **Boolean Expressions** is an expression that is either true or false like

# %%
#in programming use of = is to assign a value to it like a=3 and double equals(a==3) mean to put a question like a is equale to 3 or not
3==3 # it means 3 is equal to 3 or not? Yes, it's equale(true)
# Out:
# True

# %%
4==3 #it means 4 is equal to 3 or not? No, it's not equal(false)
# Out:
# False

# %%
#check data type of false or true
type(False)
# Out:
# bool

# %%
x=2
y=3
x is y # x is the same as y
# Out:
# False

# %%
x is not y # x is not the same as y
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Logical operators** There are three logical operators: and, or, not
#
# *  or ( returns true, if either of the conditions is true) it is same as || in C++
# *   and (returns true,if all the conditions are true) it is same as && in C++

# %%
x==3 and y<3 #x and y is already declred above
# Out:
# False

# %%
x==2 and y==3
# Out:
# True

# %%
x==2 or y<3
# Out:
# True

# %%
not(x>y) #not (x > y) is true if x > y is false
#this statement means that x is not greater than y
# Out:
# True

# %%
x >= 2 and (x/y) < 2
# Out:
# True

# %% [markdown]
# **Conditional Execution**

# %%
if y > x : #We end the if statement with a colon character (:) and the line(s) after the if statement are indented.
  print('y is greater than x' )
# Out:
# y is greater than x

# %%
if x > y : #matlab ka chari x da y na ghat v
  print('x is greater than y' )
else : #it means if the above comdition doesn't hold
  print('x is not greater than y' )
# Out:
# x is not greater than y

# %%
a=9
b=6

# %%
if a>b :
  pass # means to execute the inteded portion
  c=a+b
  print('c= ',c)
# Out:
# c=  15

# %% [markdown]
# **Alternative Execution**

# %%
if a<b :
  pass # now it will not execute the inteded portion beause a is not less than b
  c=a+b
  print('c= ',c)
else :
  print('unable to execute the inteded portion')
# Out:
# unable to execute the inteded portion

# %% [markdown]
# **A Number is Odd or Even**

# %%
if a%2 == 0 :
  print('a is even' )
else :
  print('a is odd' )
# Out:
# a is odd

# %% [markdown]
# **Chained Conditionals**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
if x < y:
 print('x is less than y' )
elif x > y:
 print('x is greater than y' )
else:
 print('x and y are equal' )
# Out:
# x is less than y

# %%
choice='b' #the intended portion will only execute for choice=b 
if choice == 'a' :
 print('Bad guess' )
elif choice == 'b' :
 print('Good guess' )
elif choice == 'c' :
 print('Close, but not correct' )
# Out:
# Good guess

# %% [markdown]
# **Nested Conditionals** just to put conditional statements in intended portion of another conditional statement

# %%
if x == y:
 print('x and y are equal' )
else:
 if x < y:
  print ('x is less than y' )
 else:
  print('x is greater than y' ) #focus on indendation
# Out:
# x is less than y

# %% [markdown]
# **Execrise**
#
#
# 1.   **write code for a simple calculator using conditional satements.**
#
# 2.   **Write a code that will take three numbers from user and will print the greatest and samllest number. How you will handle the situation if user is to enter equal numbers i.e; a=3, b=3, c=3 or a=3, b=3, c=7.**
